# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# ...
#      |████████████████████████████████| 5.8MB 6.5MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
BeautifulSoup('test','lxml')
# Out:
# <html><body><p>test</p></body></html>

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
title = soup.title
print(title)
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %%
text = soup.get_text()

# %%
rows = soup.find_all('tr')
print(rows[:10])
# Out:
# [<tr>
# <th>Postal code
# </th>
# <th>Borough
# </th>
# <th>Neighborhood
# </th></tr>, <tr>
# <td>M1A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>, <tr>
# <td>M2A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>, <tr>
# <td>M3A
# </td>
# <td>North York
# </td>
# <td>Parkwoods
# </td></tr>, <tr>
# <td>M4A
# </td>
# <td>North York
# </td>
# <td>Victoria Village
# </td></tr>, <tr>
# <td>M5A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Regent Park / Harbourfront
# </td></tr>, <tr>
# <td>M6A
# </td>
# <td>North York
# </td>
# <td>Lawrence Manor / Lawrence Heights
# </td></tr>, <tr>
# <td>M7A
# </td>
# <td>Downtown Toronto
# </td>
# <td>Queen's Park / Ontario Provincial Government
# </td></tr>, <tr>
# <td>M8A
# </td>
# <td>Not assigned
# </td>
# <td>
# </td></tr>, <tr>
# <td>M9A
# </td>
# <td>Etobicoke
# </td>
# <td>Islington Avenue
# </td></tr>]

# %%
for row in rows:
    row_td = row.find_all('td')
print(row_td)
type(row_td)
# Out:
# [<td align="center" style="border: 1px solid #FF0000; background-color: #FFE0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_A" title="List of postal codes of Canada: A">A</a>
# </td>, <td align="center" style="border: 1px solid #FF4000; background-color: #FFE8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_B" title="List of postal codes of Canada: B">B</a>
# </td>, <td align="center" style="border: 1px solid #FF8000; background-color: #FFF0E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_C" title="List of postal codes of Canada: C">C</a>
# </td>, <td align="center" style="border: 1px solid #FFC000; background-color: #FFF8E0; font-size: 135%;" width="5%"><a href="/wiki/List_of_postal_codes_of_Canada:_E" title="List of postal codes of Canada: E">E</a>
# ...

# %%
list_rows = []
for row in rows:
    row_td = row.find_all('td')
    str_cells = str(row_td)
    cleantext = BeautifulSoup(str_cells,"lxml").get_text()
    list_rows.append(cleantext)
    print(cleantext)
    type(cleantext)
# Out:
# []
# [M1A
# , Not assigned
# ,
# ]
# [M2A
# , Not assigned
# ,
# ]
# [M3A
# , North York
# , Parkwoods
# ]
# [M4A
# , North York
# , Victoria Village
# ]
# [M5A
# , Downtown Toronto
# , Regent Park / Harbourfront
# ]
# [M6A
# , North York
# , Lawrence Manor / Lawrence Heights
# ]
# [M7A
# , Downtown Toronto
# , Queen's Park / Ontario Provincial Government
# ]
# [M8A
# , Not assigned
# ,
# ]
# [M9A
# , Etobicoke
# , Islington Avenue
# ]
# [M1B
# , Scarborough
# , Malvern / Rouge
# ]
# [M2B
# , Not assigned
# ,
# ]
# [M3B
# , North York
# , Don Mills
# ]
# [M4B
# , East York
# , Parkview Hill / Woodbine Gardens
# ]
# [M5B
# , Downtown Toronto
# , Garden District, Ryerson
# ]
# [M6B
# , North York
# , Glencairn
# ]
# [M7B
# , Not assigned
# ,
# ]
# [M8B
# , Not assigned
# ,
# ]
# [M9B
# , Etobicoke
# , West Deane Park / Princess Gardens / Martin Grove / Islington / Cloverdale
# ]
# [M1C
# , Scarborough
# , Rouge Hill / Port Union / Highland Creek
# ]
# [M2C
# , Not assigned
# ,
# ]
# ...

# %%
import re
list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '', str_cells))
    list_rows.append(clean2)
    print(clean2)
    type(clean2)
# Out:
# []
# [M1A
# , Not assigned
# ,
# ]
# [M2A
# , Not assigned
# ,
# ]
# [M3A
# , North York
# , Parkwoods
# ]
# [M4A
# , North York
# , Victoria Village
# ]
# [M5A
# , Downtown Toronto
# , Regent Park / Harbourfront
# ]
# [M6A
# , North York
# , Lawrence Manor / Lawrence Heights
# ]
# [M7A
# , Downtown Toronto
# , Queen's Park / Ontario Provincial Government
# ]
# [M8A
# , Not assigned
# ,
# ]
# [M9A
# , Etobicoke
# , Islington Avenue
# ]
# [M1B
# , Scarborough
# , Malvern / Rouge
# ]
# [M2B
# , Not assigned
# ,
# ]
# [M3B
# , North York
# , Don Mills
# ]
# [M4B
# , East York
# , Parkview Hill / Woodbine Gardens
# ]
# [M5B
# , Downtown Toronto
# , Garden District, Ryerson
# ]
# [M6B
# , North York
# , Glencairn
# ]
# [M7B
# , Not assigned
# ,
# ]
# [M8B
# , Not assigned
# ,
# ]
# [M9B
# , Etobicoke
# , West Deane Park / Princess Gardens / Martin Grove / Islington / Cloverdale
# ]
# [M1C
# , Scarborough
# , Rouge Hill / Port Union / Highland Creek
# ]
# [M2C
# , Not assigned
# ,
# ]
# ...

# %%
Postal_Codes = pd.DataFrame(list_rows)
Postal_Codes.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                        [M1A\n, Not assigned\n, \n]
# 2                        [M2A\n, Not assigned\n, \n]
# 3                 [M3A\n, North York\n, Parkwoods\n]
# 4          [M4A\n, North York\n, Victoria Village\n]
# 5  [M5A\n, Downtown Toronto\n, Regent Park / Harb...
# 6  [M6A\n, North York\n, Lawrence Manor / Lawrenc...
# 7  [M7A\n, Downtown Toronto\n, Queen's Park / Ont...
# 8                        [M8A\n, Not assigned\n, \n]
# 9           [M9A\n, Etobicoke\n, Islington Avenue\n]

# %%
Postalcodes = Postal_Codes[0].str.split(',', expand = True)
Postalcodes.head(10)
# Out:
#        0                    1   \
# 0      []                 None
# 1  [M1A\n       Not assigned\n
# 2  [M2A\n       Not assigned\n
# 3  [M3A\n         North York\n
# 4  [M4A\n         North York\n
# 5  [M5A\n   Downtown Toronto\n
# 6  [M6A\n         North York\n
# 7  [M7A\n   Downtown Toronto\n
# 8  [M8A\n       Not assigned\n
# 9  [M9A\n          Etobicoke\n
#
#                                                  2     3     4     5     6   \
# 0                                              None  None  None  None  None
# 1                                               \n]  None  None  None  None
# 2                                               \n]  None  None  None  None
# 3                                      Parkwoods\n]  None  None  None  None
# 4                               Victoria Village\n]  None  None  None  None
# 5                     Regent Park / Harbourfront\n]  None  None  None  None
# 6              Lawrence Manor / Lawrence Heights\n]  None  None  None  None
# ...

# %%
df = Postalcodes.drop(Postalcodes.columns[3:31], axis=1)
df.head(10)
# Out:
#         0                    1  \
# 0      []                 None
# 1  [M1A\n       Not assigned\n
# 2  [M2A\n       Not assigned\n
# 3  [M3A\n         North York\n
# 4  [M4A\n         North York\n
# 5  [M5A\n   Downtown Toronto\n
# 6  [M6A\n         North York\n
# 7  [M7A\n   Downtown Toronto\n
# 8  [M8A\n       Not assigned\n
# 9  [M9A\n          Etobicoke\n
#
#                                                   2
# 0                                              None
# 1                                               \n]
# 2                                               \n]
# 3                                      Parkwoods\n]
# 4                               Victoria Village\n]
# 5                     Regent Park / Harbourfront\n]
# 6              Lawrence Manor / Lawrence Heights\n]
# 7   Queen's Park / Ontario Provincial Government\n]
# 8                                               \n]
# 9                               Islington Avenue\n]

# %%
df[0] = df[0].str.strip('[')
df.head(10)
# Out:
#        0                    1  \
# 0      ]                 None
# 1  M1A\n       Not assigned\n
# 2  M2A\n       Not assigned\n
# 3  M3A\n         North York\n
# 4  M4A\n         North York\n
# 5  M5A\n   Downtown Toronto\n
# 6  M6A\n         North York\n
# 7  M7A\n   Downtown Toronto\n
# 8  M8A\n       Not assigned\n
# 9  M9A\n          Etobicoke\n
#
#                                                   2
# 0                                              None
# 1                                               \n]
# 2                                               \n]
# 3                                      Parkwoods\n]
# 4                               Victoria Village\n]
# 5                     Regent Park / Harbourfront\n]
# 6              Lawrence Manor / Lawrence Heights\n]
# 7   Queen's Park / Ontario Provincial Government\n]
# 8                                               \n]
# 9                               Islington Avenue\n]

# %%
df[2] = df[2].str.strip('\n]')
df.head(10)
# Out:
#        0                    1                                              2
# 0      ]                 None                                           None
# 1  M1A\n       Not assigned\n
# 2  M2A\n       Not assigned\n
# 3  M3A\n         North York\n                                      Parkwoods
# 4  M4A\n         North York\n                               Victoria Village
# 5  M5A\n   Downtown Toronto\n                     Regent Park / Harbourfront
# 6  M6A\n         North York\n              Lawrence Manor / Lawrence Heights
# 7  M7A\n   Downtown Toronto\n   Queen's Park / Ontario Provincial Government
# 8  M8A\n       Not assigned\n
# 9  M9A\n          Etobicoke\n                               Islington Avenue

# %%
col_labels = soup.find_all('th')

# %%
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)
print(all_header)
# Out:
# ['[Postal code\n, Borough\n, Neighborhood\n, Canadian postal codes\n]']

# %%
PCHeaders = pd.DataFrame(all_header)
PCHeaders.head()
# Out:
#                                                    0
# 0  [Postal code\n, Borough\n, Neighborhood\n, Can...

# %%
PCHeaders = PCHeaders[0].str.split(',', expand = True)
PCHeaders.head()
# Out:
#                 0           1                2                          3
# 0  [Postal code\n   Borough\n   Neighborhood\n   Canadian postal codes\n]

# %%
PCHeaders = PCHeaders.drop(PCHeaders.columns[3], axis=1)
PCHeaders.head()
# Out:
#                 0           1                2
# 0  [Postal code\n   Borough\n   Neighborhood\n

# %%
PCHeaders[0] = PCHeaders[0].str.strip('\n')
PCHeaders.head(10)
# Out:
#              0           1              2
# 0  Postal code   Borough\n   Neighborhood

# %%
PCHeaders[1] = PCHeaders[1].str.strip('\n')
PCHeaders.head(10)
# Out:
#              0         1              2
# 0  Postal code   Borough   Neighborhood

# %%
frames = [PCHeaders, df]

Postal_Codes_Canada = pd.concat(frames)
Postal_Codes_Canada.head(10)
# Out:
#              0                    1  \
# 0  Postal code              Borough
# 0            ]                 None
# 1        M1A\n       Not assigned\n
# 2        M2A\n       Not assigned\n
# 3        M3A\n         North York\n
# 4        M4A\n         North York\n
# 5        M5A\n   Downtown Toronto\n
# 6        M6A\n         North York\n
# 7        M7A\n   Downtown Toronto\n
# 8        M8A\n       Not assigned\n
#
#                                                2
# 0                                   Neighborhood
# 0                                           None
# 1
# 2
# 3                                      Parkwoods
# 4                               Victoria Village
# 5                     Regent Park / Harbourfront
# 6              Lawrence Manor / Lawrence Heights
# 7   Queen's Park / Ontario Provincial Government
# 8

# %%
Postal_Canada = Postal_Codes_Canada.rename(columns=Postal_Codes_Canada.iloc[0])
Postal_Canada.head(10)
# Out:
#    Postal code              Borough  \
# 0  Postal code              Borough
# 0            ]                 None
# 1        M1A\n       Not assigned\n
# 2        M2A\n       Not assigned\n
# 3        M3A\n         North York\n
# 4        M4A\n         North York\n
# 5        M5A\n   Downtown Toronto\n
# 6        M6A\n         North York\n
# 7        M7A\n   Downtown Toronto\n
# 8        M8A\n       Not assigned\n
#
#                                     Neighborhood
# 0                                   Neighborhood
# 0                                           None
# 1
# 2
# 3                                      Parkwoods
# 4                               Victoria Village
# 5                     Regent Park / Harbourfront
# 6              Lawrence Manor / Lawrence Heights
# 7   Queen's Park / Ontario Provincial Government
# 8

# %%
Postal_Canada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186 entries, 0 to 184
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Postal code    186 non-null    object
#  1    Borough       185 non-null    object
#  2    Neighborhood  184 non-null    object
# dtypes: object(3)
# memory usage: 5.8+ KB

# %%
Postal_Canada.shape
# Out:
# (186, 3)

# %%
Postal = Postal_Canada.dropna(axis=0, how='any')
Postal.head(10)
# Out:
#    Postal code              Borough  \
# 0  Postal code              Borough
# 1        M1A\n       Not assigned\n
# 2        M2A\n       Not assigned\n
# 3        M3A\n         North York\n
# 4        M4A\n         North York\n
# 5        M5A\n   Downtown Toronto\n
# 6        M6A\n         North York\n
# 7        M7A\n   Downtown Toronto\n
# 8        M8A\n       Not assigned\n
# 9        M9A\n          Etobicoke\n
#
#                                     Neighborhood
# 0                                   Neighborhood
# 1
# 2
# 3                                      Parkwoods
# 4                               Victoria Village
# 5                     Regent Park / Harbourfront
# 6              Lawrence Manor / Lawrence Heights
# 7   Queen's Park / Ontario Provincial Government
# 8
# 9                               Islington Avenue

# %%
Postal.columns
# Out:
# Index(['Postal code', ' Borough', ' Neighborhood'], dtype='object')

# %%
Postal.dtypes
# Out:
# Postal code      object
#  Borough         object
#  Neighborhood    object
# dtype: object

# %%
Postal = Postal.drop(Postal.index[0])
Postal.head(10)
# Out:
#    Postal code              Borough  \
# 1        M1A\n       Not assigned\n
# 2        M2A\n       Not assigned\n
# 3        M3A\n         North York\n
# 4        M4A\n         North York\n
# 5        M5A\n   Downtown Toronto\n
# 6        M6A\n         North York\n
# 7        M7A\n   Downtown Toronto\n
# 8        M8A\n       Not assigned\n
# 9        M9A\n          Etobicoke\n
# 10       M1B\n        Scarborough\n
#
#                                      Neighborhood
# 1
# 2
# 3                                       Parkwoods
# 4                                Victoria Village
# 5                      Regent Park / Harbourfront
# 6               Lawrence Manor / Lawrence Heights
# 7    Queen's Park / Ontario Provincial Government
# 8
# 9                                Islington Avenue
# 10                                Malvern / Rouge

# %%
indexNames = Postal[Postal [' Borough'] == ' Not assigned' ].index
Postal.drop(indexNames , inplace=True)
Postal.head(10)
# Out:
#    Postal code       Borough  \
# 1            A             B
# 3          M1B   Scarborough
# 4          M1C   Scarborough
# 5          M1E   Scarborough
# 6          M1G   Scarborough
# 7          M1H   Scarborough
# 8          M1J   Scarborough
# 9          M1K   Scarborough
# 10         M1L   Scarborough
# 11         M1M   Scarborough
#
#                                          Neighborhood
# 1                                                   C
# 3                                     Malvern / Rouge
# 4            Rouge Hill / Port Union / Highland Creek
# 5                 Guildwood / Morningside / West Hill
# 6                                              Woburn
# 7                                           Cedarbrae
# 8                                 Scarborough Village
# 9       Kennedy Park / Ionview / East Birchmount Park
# 10                  Golden Mile / Clairlea / Oakridge
# 11   Cliffside / Cliffcrest / Scarborough Village ...

# %%
Postal.dtypes
# Out:
# Postal code      object
#  Borough         object
#  Neighborhood    object
# dtype: object

# %%
Postal[' Neighborhood'] = Postal[' Neighborhood'].astype('str')
Postal.head(10)
# Out:
#    Postal code       Borough  \
# 1            A             B
# 3          M1B   Scarborough
# 4          M1C   Scarborough
# 5          M1E   Scarborough
# 6          M1G   Scarborough
# 7          M1H   Scarborough
# 8          M1J   Scarborough
# 9          M1K   Scarborough
# 10         M1L   Scarborough
# 11         M1M   Scarborough
#
#                                          Neighborhood
# 1                                                   C
# 3                                     Malvern / Rouge
# 4            Rouge Hill / Port Union / Highland Creek
# 5                 Guildwood / Morningside / West Hill
# 6                                              Woburn
# 7                                           Cedarbrae
# 8                                 Scarborough Village
# 9       Kennedy Park / Ionview / East Birchmount Park
# 10                  Golden Mile / Clairlea / Oakridge
# 11   Cliffside / Cliffcrest / Scarborough Village ...

# %%
Postal = Postal.groupby(['Postal code', ' Borough'], as_index=False).sum()
Postal.head(10)
# Out:
#   Postal code       Borough                                       Neighborhood
# 0           A             B                                                  C
# 1         M1B   Scarborough                                    Malvern / Rouge
# 2         M1C   Scarborough           Rouge Hill / Port Union / Highland Creek
# 3         M1E   Scarborough                Guildwood / Morningside / West Hill
# 4         M1G   Scarborough                                             Woburn
# 5         M1H   Scarborough                                          Cedarbrae
# 6         M1J   Scarborough                                Scarborough Village
# 7         M1K   Scarborough      Kennedy Park / Ionview / East Birchmount Park
# 8         M1L   Scarborough                  Golden Mile / Clairlea / Oakridge
# 9         M1M   Scarborough   Cliffside / Cliffcrest / Scarborough Village ...

# %%
Postal['Postal code'] = Postal['Postal code'].str.strip('\n]')
Postal.head(10)
# Out:
#   Postal code       Borough                                       Neighborhood
# 0           A             B                                                  C
# 1         M1B   Scarborough                                    Malvern / Rouge
# 2         M1C   Scarborough           Rouge Hill / Port Union / Highland Creek
# 3         M1E   Scarborough                Guildwood / Morningside / West Hill
# 4         M1G   Scarborough                                             Woburn
# 5         M1H   Scarborough                                          Cedarbrae
# 6         M1J   Scarborough                                Scarborough Village
# 7         M1K   Scarborough      Kennedy Park / Ionview / East Birchmount Park
# 8         M1L   Scarborough                  Golden Mile / Clairlea / Oakridge
# 9         M1M   Scarborough   Cliffside / Cliffcrest / Scarborough Village ...

# %%
Postal[' Borough'] = Postal[' Borough'].str.strip('\n]')
Postal.head(10)
# Out:
#   Postal code       Borough                                       Neighborhood
# 0           A             B                                                  C
# 1         M1B   Scarborough                                    Malvern / Rouge
# 2         M1C   Scarborough           Rouge Hill / Port Union / Highland Creek
# 3         M1E   Scarborough                Guildwood / Morningside / West Hill
# 4         M1G   Scarborough                                             Woburn
# 5         M1H   Scarborough                                          Cedarbrae
# 6         M1J   Scarborough                                Scarborough Village
# 7         M1K   Scarborough      Kennedy Park / Ionview / East Birchmount Park
# 8         M1L   Scarborough                  Golden Mile / Clairlea / Oakridge
# 9         M1M   Scarborough   Cliffside / Cliffcrest / Scarborough Village ...

# %%
Postal = Postal.drop(Postal.index[0:1])
Postal.head(10)
# Out:
#    Postal code       Borough  \
# 1          M1B   Scarborough
# 2          M1C   Scarborough
# 3          M1E   Scarborough
# 4          M1G   Scarborough
# 5          M1H   Scarborough
# 6          M1J   Scarborough
# 7          M1K   Scarborough
# 8          M1L   Scarborough
# 9          M1M   Scarborough
# 10         M1N   Scarborough
#
#                                          Neighborhood
# 1                                     Malvern / Rouge
# 2            Rouge Hill / Port Union / Highland Creek
# 3                 Guildwood / Morningside / West Hill
# 4                                              Woburn
# 5                                           Cedarbrae
# 6                                 Scarborough Village
# 7       Kennedy Park / Ionview / East Birchmount Park
# 8                   Golden Mile / Clairlea / Oakridge
# 9    Cliffside / Cliffcrest / Scarborough Village ...
# 10                       Birch Cliff / Cliffside West

# %% [markdown]
# #### BeautifulSoup & lxml was installed
# #### Modules such as numpy, pandas, matplotlib, seaborn was imported
# #### urlopen() was used to pass the URL and the html was passed to BeautifulSoup. find_all() was used to extract useful html tags such as table rows and headers
# #### An empty list was generated, the text in between the html tags was extracted and appended to the assigned list
# #### The list is converted to a dataframe and cleaned by using the str.split()
# #### The text in between the html tags for the headers was generated by BeautifulSoup and converted to a dataframe and cleaned
# #### The two dataframes are concatenated
# #### From the new dataframe, the "Not assigned" cells in column " Borough" is dropped using drop
# #### The dataframe is then grouped by the "Postal code" and " Borough" using groupby
# #### The dataframe is displayed with its index below

# %%
Postal.shape
# Out:
# (104, 3)
